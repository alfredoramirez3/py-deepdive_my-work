# %% [markdown]
# ### What is a Module

# %%
import math

# %%
math
# Out:
# <module 'math' (built-in)>

# %%
import fractions

# %%
fractions
# Out:
# <module 'fractions' from '/home/ar3/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/fractions.py'>

# %%
junk = math

# %%
junk.sqrt(2)
# Out:
# 1.4142135623730951

# %%
junk is math
# Out:
# True

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def func():\n    a = 10\n    return a',
#   'func',
#   'func()',
#   'id(func)',
#   'globals()',
#   "f = globals()['func']",
#   "f = globals()['func']",
#   'f is func',
#   'f()',
#   "globals()['func']()",
#   'locals()',
#   'locals() is globals()',
#   'locals() is globals()',
#   'a = 100',
#   'globals()',
#   'def func():\n    a = 10\n    b = 10\n    print(locals())',
#   'def func():\n    a = 10\n    b = 10\n    print(locals())',
#   'func()',
#   'import math',
#   'math',
#   'import fractions',
#   'fractions',
#   'junk = math',
#   'junk.sqrt(2)',
#   'junk is math',
#   'globals()'],
#  '_oh': {2: <function __main__.func()>,
#   3: 10,
#   4: 140032109168896,
#   5: {...},
# ...

# %%
globals()['math']
# Out:
# <module 'math' (built-in)>

# %%
type(globals())
# Out:
# dict

# %%
type(math)
# Out:
# module

# %%
type(fractions)
# Out:
# module

# %%
id(math)
# Out:
# 140032294800976

# %%
import math

# %%
id(math)
# Out:
# 140032294800976

# %%
import sys

# %% [markdown]
# sys.modules => system cache

# %%
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module '_frozen_importlib' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  '_io': <module '_io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'posix': <module 'posix' (built-in)>,
#  '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>,
#  'time': <module 'time' (built-in)>,
#  'zipimport': <module 'zipimport' (frozen)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'codecs': <module 'codecs' (frozen)>,
#  'encodings.aliases': <module 'encodings.aliases' from '/home/ar3/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/encodings/aliases.py'>,
# ...

# %%
def is_ipython(str_val):
    return "ipython" in v.lower()
    
for i, (k, v) in enumerate(sys.modules.items()):
    # v = str(v)
    # # if "ipython" in v.lower():
    # if is_ipython(v):
    #     val_list = v.split()
    #     val= val_list[3]
    #     val_list = val.split("/")
    #     val_list = [item for item in p if "'" not in item]
    #     # print(f'"num": {i}, "module": {k}, {v}, {len(v)}, {p}, {len(p)}')
    #     print(f'"num": {i}, "module": {k}, "path": {val_list}')
    # else:
    #     print(f'"num": {i}, "module": {val}')
    v = str(v)
    # print(f'"num": {i}, "key": {k}, "value": {v.split()}')
    print(f'"num": {i}, "module": {v.split()[1:]}')
# Out:
# "num": 0, "module": ["'sys'", '(built-in)>']
# "num": 1, "module": ["'builtins'", '(built-in)>']
# "num": 2, "module": ["'_frozen_importlib'", '(frozen)>']
# "num": 3, "module": ["'_imp'", '(built-in)>']
# "num": 4, "module": ["'_thread'", '(built-in)>']
# "num": 5, "module": ["'_warnings'", '(built-in)>']
# "num": 6, "module": ["'_weakref'", '(built-in)>']
# "num": 7, "module": ["'_io'", '(built-in)>']
# "num": 8, "module": ["'marshal'", '(built-in)>']
# "num": 9, "module": ["'posix'", '(built-in)>']
# "num": 10, "module": ["'_frozen_importlib_external'", '(frozen)>']
# "num": 11, "module": ["'time'", '(built-in)>']
# "num": 12, "module": ["'zipimport'", '(frozen)>']
# "num": 13, "module": ["'_codecs'", '(built-in)>']
# "num": 14, "module": ["'codecs'", '(frozen)>']
# "num": 15, "module": ["'encodings.aliases'", 'from', "'/home/ar3/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/encodings/aliases.py'>"]
# ...

# %%
sys.modules['math']
# Out:
# <module 'math' (built-in)>

# %%
id(sys.modules['math'])
# Out:
# 140032294800976

# %%
math.__name__
# Out:
# 'math'

# %%
math.__dict__ # contains the attributes of the math module
# Out:
# {'__name__': 'math',
#  '__doc__': 'This module provides access to the mathematical functions\ndefined by the C standard.',
#  '__package__': '',
#  '__loader__': _frozen_importlib.BuiltinImporter,
#  '__spec__': ModuleSpec(name='math', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#  'acos': <function math.acos(x, /)>,
#  'acosh': <function math.acosh(x, /)>,
#  'asin': <function math.asin(x, /)>,
#  'asinh': <function math.asinh(x, /)>,
#  'atan': <function math.atan(x, /)>,
#  'atan2': <function math.atan2(y, x, /)>,
#  'atanh': <function math.atanh(x, /)>,
#  'cbrt': <function math.cbrt(x, /)>,
#  'ceil': <function math.ceil(x, /)>,
#  'copysign': <function math.copysign(x, y, /)>,
#  'cos': <function math.cos(x, /)>,
#  'cosh': <function math.cosh(x, /)>,
#  'degrees': <function math.degrees(x, /)>,
#  'dist': <function math.dist(p, q, /)>,
#  'erf': <function math.erf(x, /)>,
#  'erfc': <function math.erfc(x, /)>,
#  'exp': <function math.exp(x, /)>,
# ...

# %%
f = math.__dict__['sqrt']

# %%
f(2)
# Out:
# 1.4142135623730951

# %%
f
# Out:
# <function math.sqrt(x, /)>

# %%
import fractions

# %%
fractions.__dict__
# Out:
# {'__name__': 'fractions',
#  '__doc__': 'Fraction, infinite-precision, rational numbers.',
#  '__package__': '',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7f5bce3578f0>,
#  '__spec__': ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f5bce3578f0>, origin='/home/ar3/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/fractions.py'),
#  '__file__': '/home/ar3/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/fractions.py',
#  '__cached__': '/home/ar3/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/__pycache__/fractions.cpython-313.pyc',
#  '__builtins__': {'__name__': 'builtins',
# ...

# %%
fractions.__spec__
# Out:
# ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f5bce3578f0>, origin='/home/ar3/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/fractions.py')

# %%
type(fractions.__spec__)
# Out:
# _frozen_importlib.ModuleSpec

# %%
[e.removesuffix(')"]') for e in str(fractions.__spec__).split()[-1].split("/")[1:]]
# Out:
# ['home',
#  'ar3',
#  '.local',
#  'share',
#  'uv',
#  'python',
#  'cpython-3.13.1-linux-x86_64-gnu',
#  'lib',
#  'python3.13',
#  "fractions.py')"]

# %%
sys.__dict__
# Out:
# {'__name__': 'sys',
# ...

# %%
dir(sys)
# Out:
# ['__breakpointhook__',
#  '__displayhook__',
#  '__doc__',
#  '__excepthook__',
#  '__interactivehook__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__stderr__',
#  '__stdin__',
#  '__stdout__',
#  '__unraisablehook__',
#  '_base_executable',
#  '_baserepl',
#  '_clear_internal_caches',
#  '_clear_type_cache',
#  '_current_exceptions',
#  '_current_frames',
#  '_debugmallocstats',
#  '_framework',
#  '_get_cpu_count_config',
#  '_getframe',
#  '_getframemodulename',
#  '_git',
#  '_home',
#  '_is_gil_enabled',
#  '_is_interned',
#  '_setprofileallthreads',
#  '_settraceallthreads',
#  '_stdlib_dir',
#  '_xoptions',
#  'abiflags',
#  'activate_stack_trampoline',
#  'addaudithook',
#  'api_version',
#  'argv',
#  'audit',
#  'base_exec_prefix',
#  'base_prefix',
#  'breakpointhook',
#  'builtin_module_names',
#  'byteorder',
#  'call_tracing',
#  'copyright',
#  'deactivate_stack_trampoline',
#  'displayhook',
#  'dont_write_bytecode',
#  'exc_info',
# ...

# %%
fractions.__dict__
# Out:
# {'__name__': 'fractions',
#  '__doc__': 'Fraction, infinite-precision, rational numbers.',
#  '__package__': '',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7f5bce3578f0>,
#  '__spec__': ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f5bce3578f0>, origin='/home/ar3/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/fractions.py'),
#  '__file__': '/home/ar3/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/fractions.py',
#  '__cached__': '/home/ar3/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/__pycache__/fractions.cpython-313.pyc',
#  '__builtins__': {'__name__': 'builtins',
# ...

# %%
import types

# %%
isinstance(fractions,types.ModuleType)
# Out:
# True
